# %%
# !pip install langchain
# !pip install langchain-openai

# !sudo apt install tesseract-ocr
# !pip install pytesseract

import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'
# Out:
# Collecting langchain
#   Downloading langchain-0.2.12-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.3.0,>=0.2.27 (from langchain)
#   Downloading langchain_core-0.2.28-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl.metadata (2.1 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.96-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.27->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.27->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.27->langchain) (4.12.2)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.27->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Downloading langchain-0.2.12-py3-none-any.whl (990 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.6/990.6 kB 17.2 MB/s eta 0:00:00
# Downloading langchain_core-0.2.28-py3-none-any.whl (379 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 379.9/379.9 kB 17.3 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.96-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.1/140.1 kB 9.4 MB/s eta 0:00:00
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 9.6 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Installing collected packages: tenacity, orjson, jsonpointer, jsonpatch, langsmith, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# Successfully installed jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.12 langchain-core-0.2.28 langchain-text-splitters-0.2.2 langsmith-0.1.96 orjson-3.10.6 tenacity-8.5.0
# Collecting langchain-openai
#   Downloading langchain_openai-0.1.20-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.26 in /usr/local/lib/python3.10/dist-packages (from langchain-openai) (0.2.28)
# Collecting openai<2.0.0,>=1.32.0 (from langchain-openai)
#   Downloading openai-1.38.0-py3-none-any.whl.metadata (22 kB)
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.26->langchain-openai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.26->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.26->langchain-openai) (0.1.96)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.26->langchain-openai) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.26->langchain-openai) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.26->langchain-openai) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.26->langchain-openai) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai<2.0.0,>=1.32.0->langchain-openai)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (4.66.4)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain-openai) (2.31.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.32.0->langchain-openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.32.0->langchain-openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.32.0->langchain-openai) (2024.7.4)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai<2.0.0,>=1.32.0->langchain-openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.32.0->langchain-openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.26->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.26->langchain-openai) (3.10.6)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.26->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.26->langchain-openai) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.0.7)
# Downloading langchain_openai-0.1.20-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.5 MB/s eta 0:00:00
# Downloading openai-1.38.0-py3-none-any.whl (335 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 335.9/335.9 kB 11.0 MB/s eta 0:00:00
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.6 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.0 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.9 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: h11, tiktoken, httpcore, httpx, openai, langchain-openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 langchain-openai-0.1.20 openai-1.38.0 tiktoken-0.7.0
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 45 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 1s (3,981 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 123598 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-eng_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.1.1-2.1build1_amd64.deb ...
# Unpacking tesseract-ocr (4.1.1-2.1build1) ...
# Setting up tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr (4.1.1-2.1build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (24.1)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (9.4.0)
# Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.10

# %%
import os
import csv
from PIL import Image
import pytesseract
from typing import List, Optional
from langchain_openai import ChatOpenAI
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_core.prompts import ChatPromptTemplate

pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

api_key = "api-key-here"

llm = ChatOpenAI(model="gpt-4", api_key=api_key, temperature=0)

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are an expert in extracting detailed information from resumes. "
            "Your task is to identify and extract the following details from the provided resume text: "
            "- Candidate's full name "
            "- Contact information including phone number, email address, and LinkedIn profile "
            "- Educational background (degree, major, institution, and graduation date) "
            "- Professional experience (job title, company, duration, and key responsibilities) "
            "- List of skills (enumerate each skill separately) "
            "- Awards and honors "
            "- Certifications "
            "- Projects "
            "If any information is not available, indicate 'N/A' for that field. "
            "Ensure that you adhere strictly to the specified format and provide no additional commentary or explanations."
        ),
        ("human", "{text}"),
    ]
)

class Education(BaseModel):
    degree: str
    major: str
    institution: str
    graduation_date: str

class WorkExperience(BaseModel):
    job_title: str
    company: str
    duration: str
    responsibilities: str

class ResumeData(BaseModel):
    full_name: str
    phone_number: Optional[str]
    email: Optional[str]
    linkedin_profile: Optional[str]
    education: List[Education]
    work_experience: List[WorkExperience]
    skills: List[str]
    awards_and_honors: List[str]
    certifications: List[str]
    projects: List[str]

runnable = prompt | llm.with_structured_output(schema=ResumeData)

def perform_ocr(image_path):
    image = Image.open(image_path)
    ocr_text = pytesseract.image_to_string(image)
    return ocr_text

def extract_structured_data(text):
    result = runnable.invoke({"text": text})
    return result

def process_document(image_path):
    ocr_text = perform_ocr(image_path)
    if ocr_text:
        structured_data = extract_structured_data(ocr_text)
        return structured_data
    return None

def save_data_to_csv(data, csv_filename="documents.csv"):
    header = [
        "full_name", "phone_number", "email", "linkedin_profile",
        "degree1", "major1", "institution1", "graduation_date1",
        "degree2", "major2", "institution2", "graduation_date2",
        "job_title1", "company1", "duration1", "responsibilities1",
        "job_title2", "company2", "duration2", "responsibilities2",
        "skills", "awards_and_honors", "certifications", "projects"
    ]

    with open(csv_filename, mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=header)
        writer.writeheader()
        for item in data:
            item_dict = item.dict()
            flat_item_dict = {
                "full_name": item_dict["full_name"],
                "phone_number": item_dict.get("phone_number", "N/A"),
                "email": item_dict.get("email", "N/A"),
                "linkedin_profile": item_dict.get("linkedin_profile", "N/A"),
                "degree1": item_dict["education"][0]['degree'] if len(item_dict["education"]) > 0 else "N/A",
                "major1": item_dict["education"][0]['major'] if len(item_dict["education"]) > 0 else "N/A",
                "institution1": item_dict["education"][0]['institution'] if len(item_dict["education"]) > 0 else "N/A",
                "graduation_date1": item_dict["education"][0]['graduation_date'] if len(item_dict["education"]) > 0 else "N/A",
                "degree2": item_dict["education"][1]['degree'] if len(item_dict["education"]) > 1 else "N/A",
                "major2": item_dict["education"][1]['major'] if len(item_dict["education"]) > 1 else "N/A",
                "institution2": item_dict["education"][1]['institution'] if len(item_dict["education"]) > 1 else "N/A",
                "graduation_date2": item_dict["education"][1]['graduation_date'] if len(item_dict["education"]) > 1 else "N/A",
                "job_title1": item_dict["work_experience"][0]['job_title'] if len(item_dict["work_experience"]) > 0 else "N/A",
                "company1": item_dict["work_experience"][0]['company'] if len(item_dict["work_experience"]) > 0 else "N/A",
                "duration1": item_dict["work_experience"][0]['duration'] if len(item_dict["work_experience"]) > 0 else "N/A",
                "responsibilities1": item_dict["work_experience"][0]['responsibilities'] if len(item_dict["work_experience"]) > 0 else "N/A",
                "job_title2": item_dict["work_experience"][1]['job_title'] if len(item_dict["work_experience"]) > 1 else "N/A",
                "company2": item_dict["work_experience"][1]['company'] if len(item_dict["work_experience"]) > 1 else "N/A",
                "duration2": item_dict["work_experience"][1]['duration'] if len(item_dict["work_experience"]) > 1 else "N/A",
                "responsibilities2": item_dict["work_experience"][1]['responsibilities'] if len(item_dict["work_experience"]) > 1 else "N/A",
                "skills": "; ".join(item_dict.get("skills", [])),
                "awards_and_honors": "; ".join(item_dict.get("awards_and_honors", [])),
                "certifications": "; ".join(item_dict.get("certifications", [])),
                "projects": "; ".join(item_dict.get("projects", []))
            }
            writer.writerow(flat_item_dict)

def process_multiple_documents(directory_path, csv_filename="documents.csv"):
    results = []
    for filename in os.listdir(directory_path):
        if filename.endswith((".png", ".jpg", ".jpeg", ".pdf")):
            image_path = os.path.join(directory_path, filename)
            data = process_document(image_path)
            if data:
                results.append(data)
    save_data_to_csv(results, csv_filename)
    return results

directory_path = "/content/myresume_v1"
all_data = process_multiple_documents(directory_path)
for data in all_data:
    print(data)
# Out:
# full_name='Raviteja Moolinti Nallakkagari' phone_number='716-936-6677' email='mnoolint@buffalo.edu' linkedin_profile='www.linkedin.com/in/munraviteja' education=[Education(degree='MS in Computer Science and Engineering (AI/ML Track)', major='Computer Science and Engineering', institution='University at Buffalo, The State University of New York', graduation_date='December 2024'), Education(degree='Bachelor of Technology in Computer Science and Engineering', major='Computer Science and Engineering', institution='Sri Venkateswara University', graduation_date='June 2022')] work_experience=[WorkExperience(job_title='Research Assistant', company='University at Buffalo, The State University of New York', duration='January 2023 - Present', responsibilities='Employed Large Language Models (LLMs) with prompt engineering to extract synthesis and activation conditions from 1000+ MOF research papers, achieving 96% accuracy. Implemented predictive models correlating synthesis parameters with material performance metrics, reducing trial-and-error by 75% and saving 10 hours per experiment, optimizing experimental planning. Streamlined data processing and analysis workflows, reducing manual effort by 50% and time spent on data extraction and analysis by 30%. Automated scraping of research articles using Python and Selenium, efficiently gathering large dataset for analysis.'), WorkExperience(job_title='Associate Software Engineer (Machine Learning Engineer)', company='Infor', duration='October 2022 - August 2023', responsibilities='Collaborated to develop an NLP system that translates natural language queries into structured SQL queries, aiding customers with limited SQL knowledge. Leveraged Hugging Face models to develop and deploy text summarization tools, reducing processing time by 30%. Delivered measurable results within weeks, including anomaly detection, pricing decisions, cost reduction, and demand forecasting. Increased cross-selling revenue by 20% by implementing personalized product recommendations based on customer behavior and historical data.'), WorkExperience(job_title='Development Intern', company='Infor', duration='April 2022 - October 2022', responsibilities='Engaged in cross-functional collaboration to collect requirements, build, and evaluate models and present findings to customers. Enhanced SQL queries to boost data extraction efficiency, lessening processing times by 40%, and decreasing average query time from 10 seconds to 6 seconds. Utilized PySpark for handling large-scale data, lowering response times to under 1 second for most use cases via the Infor ION API Gateway, enhancing real-time data processing by 20%. Configured workflows for periodic execution of ML pipelines, automating retraining with new data to reduce manual intervention by 50% and save 10 hours weekly.'), WorkExperience(job_title='Intern', company='Codinza', duration='March 2019 - July 2019', responsibilities='Designed and deployed dynamic web applications using MongoDB, Express, React, and NodeJS (MERN stack). Created responsive UIs and RESTful APIs, decreasing bug reports by 40%.')] skills=['Python', 'C', 'C#', 'R', 'PyTorch', 'Tensorflow', 'PySpark', 'MySQL', 'PostgreSQL', 'MongoDB', 'React', 'Node.js(Express)', 'Flask', 'Generative AI', 'Machine Learning', 'Deep Learning', 'RL', 'Docker', 'Git', 'VS Code', 'AWS'] awards_and_honors=['Won the Institute Innovation Cell Award among 600+ students for adding attendance management and alumni connections to college website.', 'Mentored students by conducting over 20+ sessions on machine learning as a part of instructional team of coding club at Sri Venkateswara University.'] certifications=[] projects=['Language translation: Developed and trained multiple models for English to German translation, including LSTM, GRU, LSTM with attention, and Transformer architectures. Fine-tuned the mT5 model, achieving a BLEU score of 40.25 on the Multi30k dataset, ranking in the top 3 scores to date.', 'Network Intrusion ...

# %%
import os
import csv
from PIL import Image
import pytesseract
from typing import List, Optional
from langchain_openai import ChatOpenAI
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_core.prompts import ChatPromptTemplate

pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

api_key = "api-key-here"

llm = ChatOpenAI(model="gpt-4", api_key=api_key, temperature=0)

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are an expert in extracting detailed information from resumes. "
            "Your task is to identify and extract the following details from the provided resume text: "
            "- Candidate's full name "
            "- Contact information including phone number, email address, and LinkedIn profile "
            "- Educational background (degree, major, institution, and graduation date) "
            "- Professional experience (job title, company, duration, and key responsibilities) "
            "- List of skills (enumerate each skill separately) "
            "- Awards and honors "
            "- Certifications "
            "- Projects "
            "If any information is not available, indicate 'N/A' for that field. "
            "Ensure that you adhere strictly to the specified format and provide no additional commentary or explanations."
        ),
        ("human", "{text}"),
    ]
)

class Education(BaseModel):
    degree: str
    major: str
    institution: str
    graduation_date: str

class WorkExperience(BaseModel):
    job_title: str
    company: str
    duration: str
    responsibilities: str

class ResumeData(BaseModel):
    full_name: str
    phone_number: Optional[str]
    email: Optional[str]
    linkedin_profile: Optional[str]
    education: List[Education]
    work_experience: List[WorkExperience]
    skills: List[str]
    awards_and_honors: List[str]
    certifications: List[str]
    projects: List[str]

runnable = prompt | llm.with_structured_output(schema=ResumeData)

def perform_ocr(image_path):
    image = Image.open(image_path)
    ocr_text = pytesseract.image_to_string(image)
    return ocr_text

def extract_structured_data(text):
    result = runnable.invoke({"text": text})
    return result

def process_document(image_path):
    ocr_text = perform_ocr(image_path)
    if ocr_text:
        structured_data = extract_structured_data(ocr_text)
        return structured_data
    return None

def save_data_to_csv(data, csv_filename="documents.csv"):
    header = [
        "full_name", "phone_number", "email", "linkedin_profile",
        "degree1", "major1", "institution1", "graduation_date1",
        "degree2", "major2", "institution2", "graduation_date2",
        "job_title1", "company1", "duration1", "responsibilities1",
        "job_title2", "company2", "duration2", "responsibilities2",
        "skills", "awards_and_honors", "certifications", "projects"
    ]

    with open(csv_filename, mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=header)
        writer.writeheader()
        for item in data:
            item_dict = item.dict()
            flat_item_dict = {
                "full_name": item_dict["full_name"],
                "phone_number": item_dict.get("phone_number", "N/A"),
                "email": item_dict.get("email", "N/A"),
                "linkedin_profile": item_dict.get("linkedin_profile", "N/A"),
                "degree1": item_dict["education"][0]['degree'] if len(item_dict["education"]) > 0 else "N/A",
                "major1": item_dict["education"][0]['major'] if len(item_dict["education"]) > 0 else "N/A",
                "institution1": item_dict["education"][0]['institution'] if len(item_dict["education"]) > 0 else "N/A",
                "graduation_date1": item_dict["education"][0]['graduation_date'] if len(item_dict["education"]) > 0 else "N/A",
                "degree2": item_dict["education"][1]['degree'] if len(item_dict["education"]) > 1 else "N/A",
                "major2": item_dict["education"][1]['major'] if len(item_dict["education"]) > 1 else "N/A",
                "institution2": item_dict["education"][1]['institution'] if len(item_dict["education"]) > 1 else "N/A",
                "graduation_date2": item_dict["education"][1]['graduation_date'] if len(item_dict["education"]) > 1 else "N/A",
                "job_title1": item_dict["work_experience"][0]['job_title'] if len(item_dict["work_experience"]) > 0 else "N/A",
                "company1": item_dict["work_experience"][0]['company'] if len(item_dict["work_experience"]) > 0 else "N/A",
                "duration1": item_dict["work_experience"][0]['duration'] if len(item_dict["work_experience"]) > 0 else "N/A",
                "responsibilities1": item_dict["work_experience"][0]['responsibilities'] if len(item_dict["work_experience"]) > 0 else "N/A",
                "job_title2": item_dict["work_experience"][1]['job_title'] if len(item_dict["work_experience"]) > 1 else "N/A",
                "company2": item_dict["work_experience"][1]['company'] if len(item_dict["work_experience"]) > 1 else "N/A",
                "duration2": item_dict["work_experience"][1]['duration'] if len(item_dict["work_experience"]) > 1 else "N/A",
                "responsibilities2": item_dict["work_experience"][1]['responsibilities'] if len(item_dict["work_experience"]) > 1 else "N/A",
                "skills": "; ".join(item_dict.get("skills", [])),
                "awards_and_honors": "; ".join(item_dict.get("awards_and_honors", [])),
                "certifications": "; ".join(item_dict.get("certifications", [])),
                "projects": "; ".join(item_dict.get("projects", []))
            }
            writer.writerow(flat_item_dict)

def process_multiple_documents(directory_path, csv_filename="documents.csv"):
    results = []
    for filename in os.listdir(directory_path):
        if filename.endswith((".png", ".jpg", ".jpeg", ".pdf")):
            image_path = os.path.join(directory_path, filename)
            data = process_document(image_path)
            if data:
                results.append(data)
    save_data_to_csv(results, csv_filename)
    return results


directory_path = "/content/resumes"
all_data = process_multiple_documents(directory_path)
for data in all_data:
    print(data)
# Out:
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[Education(degree='MBA', major='Business Administration', institution='OR. CV Raman University', graduation_date='N/A'), Education(degree='B.com', major='Commerce', institution='Gulbarga University', graduation_date='N/A')] work_experience=[WorkExperience(job_title='Software Engineer', company='Trucktion', duration='N/A', responsibilities='Designing and developing web pages using Reactjs. Redux, HTMLS, CSS3, Bootstrap, JavaScript and Material.ul. Developed the application for responsive to different screen resolution using Bootstrap and CSS3 media queries. Managing application-level state by using Redux and Redux hooks — use Dispatch, use Selector. Designing and using dynamic and reusable components. Design and develop static or dynamic components based on the requirements from product owner.'), WorkExperience(job_title='Software Engineer', company='Learning Management System (LMS)', duration='N/A', responsibilities='Learning Management System is designed to track the training of the employee. This project consists of the training allocation as individual or in group. User will be notified time to time about completion of the training. On completion of training employee will receive the Certificate. LMS also helps to rate the training or trainer based on the performance. Technical Discussion Forum is a part of LMS which helps to resolve the blocker/issues faced by individual/team. They will collaborate together and work on the resolution or technical knowledge sharing. Web App for front-end is implemented by using React JS with React Hooks, Redux, HTML5, CSS, Bootstraps, Material UI.')] skills=['Reactjs', 'Redux', 'HTML5', 'CSS3', 'Bootstrap', 'JavaScript', 'Material UI', 'Responsive Design', 'State Management', 'Component Design'] awards_and_honors=[] certifications=[] projects=['Trucktion', 'Learning Management System (LMS)']
# full_name='Aakash Sotunke' phone_number='579897022 / 7585765171' email='aakashsotunkezn9eqamaiiicom' linkedin_profile='N/A' education=[Education(degree='Bachelor of Engineering', major='N/A', institution='Pune University', graduation_date='2018'), Education(degree='HSC', major='N/A', institution='State Board, Aurangabad', graduation_date='2011'), Education(degree='SSC', major='N/A', institution='State Board, Aurangabad', graduation_date='2007')] work_experience=[WorkExperience(job_title='Data Analyst/ ML Engineer', company='System Plus Transformations, Pune', duration='2021-Present', responsibilities='Normalizing, Grouping, Cleaning data of pf, excel format and convert it into packages. Building a ML model for nearly 100s different insurance carriers for enhancing the customer experience while reducing the claims settlement time.'), WorkExperience(job_title='N/A', company='Intelligic Software Pvt Ltd, Pune', duration='June 2020 - Dec 2020', responsibilities='Auto Insurance fraud detection')] skills=['Python', 'MySQL', 'ML Model building', 'Data pre-processing using pandas & python libraries', 'Python libraries such as Matplotlib, Numpy, Pandas and Seaborn', 'Tableau', 'Microsoft', 'Jupyter Notebook'] awards_and_honors=['N/A'] certifications=['N/A'] projects=['Auto Insurance fraud detection']
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='Software Test Engineer', company='Tieto nator India Pvt. Ltd', duration='June 2019 to present', responsibilities='Analyzing & validating the completeness of business requirements, Generating the Test scenarios and Test cases.'), WorkExperience(job_title='Software Test Engineer (Intern)', company='VCITY Technology', duration='January 2019 to June 2019', responsibilities='N/A')] skills=['Good understanding of Dynamic Xpath and Itrame', 'Knowledge of handling Synchronization (Implicit, Explicit and Fluent)', 'Knowledge of handling Popups and List Box', 'Experience TestNG, Annotations and keywords', 'Experience in designing of POM (Page Object Model) classes', 'Familiar with use of MAVEN, Github, Jenkins, Listeners and Extent Reporter', 'Good communication, collaboration with proficiency at grasping new technical concepts quickly and utilize the same in a productive manner', 'Experience in SQL Programming Knowledge', 'Excellent Knowledge in MS-Office (Word, Excel, PowerPoint)', 'Functional Testing, Retesting, Regression testing, Integration Testing, Review Test cases', 'SQL Server'] awards_and_honors=[] certifications=[] projects=[]
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='Software Engineer', company='Perflelent India Pvt. Ltd', duration='Aug 2019 to present', responsibilities='Prepare reusable methods to improve productivity and maintainability. Prepare Feature files and Step definition in Cucumber. Involved in Bug fixing for the defects sized during UAT. Good experience in Resolving conflicts and Involved in Push, Pull, Merge the source code from GIT. Perform Cross browser testing and automate execution to check the compatibility. Extensively automated Regression test using Jenkins. Good in Java language programming and finding x path locators.')] skills=['Java language programming', 'Finding x path locators', 'Preparing reusable methods', 'Preparing Feature files and Step definition in Cucumber', 'Bug fixing', 'Resolving conflicts', 'GIT operations (Push, Pull, Merge)', 'Cross browser testing', 'Automated execution', 'Regression testing using Jenkins'] awards_and_honors=[] certifications=[] projects=['Kogan']
# full_name='Aniket Bharat Kakade' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[] skills=['Operating systems', 'Testing Tools', 'Databases', 'Microsoft office', 'windows xP', 'windows 7', 'Windows 10', 'JAVA', 'SL', 'Jira', 'Selenium WebDriver', 'Postman', 'SQL Server 2014', 'Word', 'PPT', 'Excel'] awards_and_honors=[] certifications=[] projects=[]
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[Education(degree='Post-Graduation Diploma', major='Customer Service', institution='N/A', graduation_date='N/A')] work_experience=[WorkExperience(job_title='N/A', company='N/A', duration='N/A', responsibilities='Conducted Campus Recruitment Training Programs in College, Organised placement drive in Westley College in Secunderabad, Organised placement drive in Methodist College in Abids, Hyd, Organised Cultural Events colleges')] skills=['JSON', 'SOAP API', 'REST API', 'GIT', 'JIRA', 'RoomDB', 'Retrofit', 'Android Studio', 'SQL', 'Microsoft Visual Studio', 'Visual XMLJAVA', 'Android', 'SQLite', 'Xamarin Forms', 'React Native'] awards_and_honors=['N/A'] certifications=['N/A'] projects=['https://play.google.com/store/apps/details?id=com.acs.engine']
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='N/A', company='N/A', duration='N/A', responsibilities='Hands-on experience in Azure Analytic Services, Azure Data Lake Store (ADLS) Gen1 and Gen2, Azure Data Factory (ADF) and Azure Data bricks. Knowledge on basic Admin tasks related to ADF like providing access to ADLS. Extensively worked on data sources types SQL server, Oracle, flat file, JSON, CSV and Excel. Knowledge on Power BI.')] skills=['Azure Analytic Services', 'Azure Data Lake Store (ADLS) Gen1', 'Azure Data Lake Store (ADLS) Gen2', 'Azure Data Factory (ADF)', 'Azure Data bricks', 'Admin tasks related to ADF', 'SQL server', 'Oracle', 'Flat file', 'JSON', 'CSV', 'Excel', 'Power BI'] awards_and_honors=[] certifications=[] projects=[]
# full_name='Jayesh Dhangar' phone_number='N/A' email='jayeshdhangar199S@email.com' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='N/A', company='Jae Bator indi Pv Ltd, Pune', duration='3 years', responsibilities='Manual and Automation testing, Functionality Testing, Non-Functional Testing, Regression Testing, API Web Service Testing, Database Testing and Automation Testing. Participated in Scrum meetings, prepared weekly status reports, implemented Agile Methodology process in the project, involved in System Integration Testing (SIT), defect log using defect management tool such as JIRA, designed the Traceability Matrix to map Business Requirements with test Case, developed SQL scripts for database testing, knowledge of UNIX commands, creating, modifying, and enhancing both manual Test cases and Test Scripts created in Selenium Web Driver, executed test scripts on IE, Firefox and Google chrome.')] skills=['Manual and Automation testing', 'Functionality Testing', 'Non-Functional Testing', 'Regression Testing', 'API Web Service Testing', 'Database Testing', 'Automation Testing', 'Scrum', 'Agile Methodology', 'System Integration Testing (SIT)', 'Defect log using JIRA', 'Traceability Matrix', 'SQL', 'UNIX commands', 'Selenium Web Driver', 'JAVA', 'OOPS Concept', 'Collection and String', 'Web elements identification using Xpath'] awards_and_honors=[] certifications=[] projects=[]
# full_name='JAYESH DHANGAR' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[] skills=['English', 'Hindi', 'Marathi'] awards_and_honors=[] certifications=[] projects=[]
# full_name='Gururajan' phone_number='soroaea7o2904' email='frurusolwetuegmaicom' linkedin_profile='N/A' education=[Education(degree='B. Com.', major='N/A', institution='DAV Jain College, Chennai', graduation_date='N/A')] work_experience=[WorkExperience(job_title='Software Development', company='N/A', duration='N/A', responsibilities='Executing prestigious projects of large magnitude within strict time schedules; managing & executing projects with 100% accuracy; designing solutions as per client needs; developing applications; planning, implementation, risk analysis, quality assurance; client engagements; operations readiness; software principles, design, implementation, deployment; Agile Team Facilitator & Scrum Master; implementing Agile methodology; knowledge of various tools & technologies including: Spring boot 2.4, Struts 2, Zk, Microsoft technologies: VBS, Excel Macro programming, Querying languages like, SQL and PL/SQL.')] skills=['Software Development', 'Delivery Management', 'Solution Architecture', 'Project Management', 'Process Automation & Simulation', 'JAVA/J2EE technologies', 'End-to-end program planning', 'Implementation', 'Risk analysis', 'Quality assurance', 'Client engagements', 'Operations readiness', 'Software principles', 'Design', 'Implementation', 'Deployment', 'Agile Team Facilitator & Scrum Master', 'Agile methodology', 'Spring boot 2.4', 'Struts 2', 'Zk', 'Microsoft technologies: VBS', 'Excel Macro programming', 'SQL', 'PL/SQL'] awards_and_honors=['N/A'] certifications=['N/A'] projects=['N/A']
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[] skills=[] awards_and_honors=[] certifications=[] projects=[]
# full_name='Onwenination £2477' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='N/A', company='247s cantoma src software and series company', duration='N/A', responsibilities='N/A')] skills=[] awards_and_honors=[] certifications=[] projects=[]
# full_name='Embarckle' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[Education(degree='ME (EEE)', major='N/A', institution='PSG College of Technology', graduation_date='2018'), Education(degree='42th', major='N/A', institution='Sti Gopal Naidu Hr see Schoo!', graduation_date='2009'), Education(degree='10th', major='N/A', institution='Sri Gopal Naidu Hr See Schoo!', graduation_date='2007')] work_experience=[WorkExperience(job_title='Software Engineer', company='Cagnizant Technology Solutions', duration='Mar 2016 to July 2018', responsibilities='Coordinating and resolving highly complex issues that arise in production environments within SLAs. Resolving user related business tickets on a day to day basis. Responsible for performing code reviews with offshore team. Implemented various PL/SQL queries for business requests. Identified the issue and fixed defects in both UAT and Prod Databases. Responsible for deployment in various environments. Identifying the root cause in code level for the issues reported by business. Prepare and review of Daily Status Reports and Weekly Status Reports. Facilitated & participated in daily stand-ups and meetings. Creating defects in Quality Center for the business approved RCA provided by us. Monitoring the application keenly to report and resolve the issue Identified before user started calling helpdesk to report the same. Facilitating team co-ordination between the business and sustain team.')] skills=['Coordinating and resolving complex issues', 'Resolving user related business tickets', 'Performing code reviews', 'Implementing PL/SQL queries', 'Identifying and fixing defects', 'Deployment in various environments', 'Identifying root cause in code level', 'Preparing and reviewing status reports', 'Facilitating and participating in meetings', 'Creating defects in Quality Center', 'Monitoring applications', 'Facilitating team co-ordination'] awards_and_honors=[] certifications=[] projects=['Ally Finance (Web Portal)', 'Ally Finance (Application Support)']
# full_name='Karan Ananthan M' phone_number='18667564011' email='karanananthanS2@gmail.com' linkedin_profile='N/A' education=[Education(degree="Bachelor's Degree", major='Electrical and Electronics Engineering', institution='Kingston Engineering College, Vellore', graduation_date='N/A')] work_experience=[WorkExperience(job_title='Job Title', company='Sphyzee rr Solutions', duration='April 2020 - Present', responsibilities='Data analysis and Tableau development, working with Adobe XD and creating wireframe and implementing in tableau, creating interactive dashboard and reports (Daily/Weekly/Monthly & Quarterly basis), configuring the Tableau server and upgrading the Tableau Server, creating various charts in tableau, basic knowledge on database like MySQL and PostgreSQL, basic knowledge in Talend, Tableau Prep')] skills=['Tableau Desktop', 'Tableau server', 'Tableau Prep', 'Talend', 'MySQL and Postgres', 'Adobe XD', 'Adobe Illustrator', 'Data Analysis', 'Visualization', 'Data Preparation', 'Tableau Calculation'] awards_and_honors=[] certifications=[] projects=[]
# full_name='akah july' phone_number='N/A' email='17e@grallcom' linkedin_profile='N/A' education=[Education(degree='PMGIE(T)', major='N/A', institution="KiT's College of Engineering, Kolhapur", graduation_date='2016'), Education(degree='HSC', major='N/A', institution='Modern Education Society', graduation_date='2011'), Education(degree='SSC', major='N/A', institution='Modern Education Society', graduation_date='2009')] work_experience=[WorkExperience(job_title='N/A', company='Goodman Manufacturing (Daikin)', duration='N/A', responsibilities='Coding in VB.NET for web controls, modules and updating')] skills=['Visual Studio 2010 and 2017', '.NET Framework', 'ASP.NET using C#', 'VB.NET', 'SQL Server 2000-2018', 'Object-oriented techniques', 'HTML5', 'CSS3', 'Javascript', 'LINQ', 'Entity Framework for Object Relational Mapping (ORM)', 'Creating Database objects (Tables, Indexes, Triggers, Views, Cursors and Stored Procedures)', '.NET security features such as Authentication & Authorization'] awards_and_honors=[] certifications=[] projects=['PAP - Program Application Process (US and Canada)']
# full_name='Balamurugan Muniyandi' phone_number='+91 9677059249' email='N/A' linkedin_profile='N/A' education=[Education(degree='B.E', major='Computer Science and Eng', institution='Coimbatore institute of Technology, Coimbatore', graduation_date='2004')] work_experience=[WorkExperience(job_title='.Net consultant', company='N/A', duration='10+ years', responsibilities='Development, Design, Dev Lead, Pre Sales')] skills=['Microsoft web technologies', 'SQL databases', 'open source tools and technologies', 'Design principles', 'patterns', 'low level design of software or module', 'agile SCRUM', 'writing clean and unit testable Cit code/component/application', 'Developed highly configurable solution for Taleo (HRMS) integration', 'Integrated GeBiz (procurement) with an Invoicing .Net app using SFTP', 'Developed .Net and PHP SDKs, for world leading payment product', 'Design Reviews', 'applying design principles [SOLID DRY YAGNI] and design patterns', 'Low level design, includes database, local layering, use case, sequence, class and deployment using UML and/or white board', 'Worked and implemented the various architecture styles including layered, messaging, client server and REST', 'High level design activities, drafting HLD document and design reviews with various stake holders such as customer, product owners, IT infrastructure, and', 'Being a technical subject matter expert', 'Won few new prospects on taleo and Microstrategy product suite', 'Provided solution or design approach to RFPs in collaboration with pre-sales team and cent', 'Experience in doing PoCs and API prototyping', 'Led team on both Agile SCRUM and Waterfall projects', 'Experience as Level 3 Dev Lead on an AMS(Application maintenance and support ) engagement for about 3+ years', 'Experience in code and design reviews of peers and other teams'] awards_and_honors=['N/A'] certifications=['N/A'] projects=['N/A']
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='N/A', company='APL Hotels', duration='N/A', responsibilities='Leading, Production Support, Development, Technical Design'), WorkExperience(job_title='N/A', company='Renault Nissan Technology', duration='N/A', responsibilities='Engage in application design analysis, developing project plans, coding, testing, documenting all code, debugging and testing application programs, interacted with multilayered databases including Oracle and SQL, worked with all levels of the business and the development team to establish, promote, and enforce simple solutions and guidelines as well as assist in the implementation and problem resolution of existing applications and requests'), WorkExperience(job_title='N/A', company='N/A', duration='N/A', responsibilities='Managed migration project from Access application, actively participated in migration milestones, proficient in Microsoft')] skills=['Java Struts', 'Spring Framework', "Active MQ'542 & 530 Oracle", 'Weblog', 'Apache Tomcat', 'Eclipse IDE', 'SAI (Part of spring) Framework', 'MySQL', 'IH0SS Developer Studio', 'Oracle 10.3 1908S Developer studio', 'Microsoft'] awards_and_honors=[] certifications=[] projects=[]
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[Education(degree='Master Of Computer Application (MCA)', major='Computer Application', institution='North Maharashtra University', graduation_date='2018')] work_experience=[WorkExperience(job_title='N/A', company='Informa, UK', duration='N/A', responsibilities='Responsible for gathering test execution data on daily basis and sending mail to Team, Responsible for getting clarification from the Development Team regarding defects, Performed Root cause analysis of all defects, Responsible for sending progress reports on the weekly basis and resolving technical issues, Responsible for providing Regression Test case Estimation for various customer requests, Performing Functional Testing and Regression Testing , Globalization Testing, CrossBrowser Testing, API Testing, UI Testing and Automation Testing using Selenium Webdriver with JAVA, Identifying test cases for Regression Suite and updating the script accordingly, Developing POM classes and Test classes, Involved in the peer review of the script and presenting demo to the chi, Used existing BDD Framework for the test script execution'), WorkExperience(job_title='N/A', company='Azzurrh tions, U', duration='N/A', responsibilities='N/A')] skills=['Functional Testing', 'Regression Testing', 'Globalization Testing', 'CrossBrowser Testing', 'API Testing', 'UI Testing', 'Automation Testing using Selenium Webdriver with JAVA', 'Identifying test cases for Regression Suite', 'Developing POM classes and Test classes', 'Peer review of the script', 'Using existing BDD Framework for the test script execution'] awards_and_honors=[] certifications=[] projects=['Informa Markets', 'Billing and CRM system']
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[Education(degree='Bachelor of Engineering', major='N/A', institution='N/A', graduation_date='N/A')] work_experience=[WorkExperience(job_title='Software Test Engineer', company='Ingenio Technology', duration='From June-2020', responsibilities='Experience in automation testing using Selenium WebDriver version 4.1.1. Used Core Java and OOPS concept to write selenium test script. Executed test scripts on different webdriver APs like Firefox and Google chrome. Worked In BDF (Data driven framework) with MAVEN project. Used TestNG unit framework and its Annotations, Assertions, Listeners and keywords for design the Test script. Experience in designing of POM (Page Object Model) classes and test classes. Knowledge of designing Utility Class and Base Class. Used VCS GitHub repository to maintain source code. Knowledge about Jenkins CI/CD Tool for scheduling test case execution. Used mostly Xpath & ID locators to identify Web elements. Used Parameterization and Screenshots methods in test scripts. Experience of handling Popups , List Box, iframes and WebTables. Grouping Test cases, prioritizing test cases, executing test batches, generating test reports , Analyzing test result and reporting defects. Significant Knowledge in Web Service Testing with the help of POSTMAN Tool. Knowledge of SOAP and REST Services. Good knowledge of Types of Requests(methods) and Services Tested. Knowledge in validating different Status Codes in responses. Implements API Web services testing.')] skills=['Automation testing using Selenium WebDriver version 4.1.1', 'Core Java and OOPS concept', 'TestNG unit framework', 'Designing of POM (Page Object Model) classes and test classes', 'Designing Utility Class and Base Class', 'VCS GitHub repository', 'Jenkins CI/CD Tool', 'Xpath & ID locators', 'Parameterization and Screenshots methods in test scripts', 'Handling Popups , List Box, iframes and WebTables', 'Web Service Testing with POSTMAN Tool', 'SOAP and REST Services', 'Types of Requests(methods) and Services Tested', 'Validating different Status Codes in responses', 'API Web services testing', 'JAVA', 'SQL', 'HTML', 'Oracle DB', 'MY SQL server', 'JIRA', 'GitHub', 'MS Word', 'Excel'] awards_and_honors=['N/A'] certifications=['N/A'] projects=['N/A']
# full_name='Jayant' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='ReactJs Developer', company='Angular Minds Pvt. Ltd.', duration='3 years', responsibilities='N/A')] skills=['React', 'React Routeredux', 'Javascript', 'HTML5', 'CSS3', 'Node JS', 'MongoDB', 'Bootstrap', 'Sass', 'Redux Flax', 'Jira', 'Trello', 'Git with Git-hub', 'Bitbucket', 'VS Code', 'CI-CD Process', 'Agile'] awards_and_honors=[] certifications=[] projects=['E sign application']
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='N/A', company='Trackurate', duration='N/A', responsibilities="Developed a mobile application to track Fleet Manager's vehicles. The application contained all the info regarding the vehicle, their live tracking. The alerts and interactive dashboards have led to effective management of the vehicles."), WorkExperience(job_title='N/A', company='DOST (Digital Operations for Smart Transportation)', duration='N/A', responsibilities='Developed a complete ERP for logistic owners to manage their records. It has more than 7 modules such as accounting, trips, tires, documents etc.'), WorkExperience(job_title='N/A', company='Wales', duration='N/A', responsibilities='Developed a wallet for fleet owners to fill fuel & pay toll tax and getting discount on every fuel filling or toll tax.'), WorkExperience(job_title='N/A', company='Partner Admin Dashboard', duration='N/A', responsibilities='Developed an application that manages all the company partner and decides which roles needs to provide to their partner and contain all the info regarding them.'), WorkExperience(job_title='N/A', company='FVTS', duration='N/A', responsibilities='Developed a web app that manages all the trucks of fleet managers. live tracking of vehicles and route optimization, performance reporting and fuel management kind of module inside it.'), WorkExperience(job_title='N/A', company='Wallets-Admin', duration='N/A', responsibilities='Developed an application that contains information regarding all the FastTrack info and all the transition on toll, containing different reports inside it for fleet managers. different kind of bank transition api also inside this project.'), WorkExperience(job_title='N/A', company='Accesslators', duration='N/A', responsibilities='Developed a website which is providing file accessibility services to the end users. This website contains Admin, Client, Remediator and Manager Portal.')] skills=['Angular', 'Ionic', 'NodeJs', 'MongoDB', 'Spring Boot', 'Hibernate', 'Microservices', 'Jenkins', 'Amazon Web Services', 'JavaScript', 'PostgreSQL', 'ExpressJs'] awards_and_honors=[] certifications=[] projects=['Trackurate', 'DOST (Digital Operations for Smart Transportation)', 'Wales', 'Partner Admin Dashboard', 'FVTS', 'Wallets-Admin', 'Accesslators']
# full_name='MD SHAUKATH AHMED' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='UI Developer', company='N/A', duration='N/A', responsibilities='Ul development by using React JS, Implementing the unique wireframe into function, Managing application level state by using local state, Responsive web design by using React Bootstrap, HTMLS, C583, Designing and using dynamic and reusable components, Implementation of connectivity with API services by using fetch')] skills=['React JS', 'HTMLS', 'C583', 'React Bootstrap', 'API services'] awards_and_honors=[] certifications=[] projects=[]
# full_name='Dharani Subramanian TN' phone_number='+91-9600296222' email='darant988@gmail.com' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='Business Analyst & Delivery Manager', company="Dream guy's Technologies", duration='2020-11 to Current', responsibilities='Build and develop the project team to ensure. Develop business architecture using requirements such as scope, processes, alternatives, and risks. Analyze project progress and, when necessary, adapt scope, timelines, and costs to ensure that project team adheres to project requirements. Establish and maintain relationships with appropriate project status and changes. Giving results and summarized into presentations. Drafted quarterly and yearly reports on company for deficiencies. Improved business direction by prioritizing customers and implementing changes based on collected'), WorkExperience(job_title='Business Analyst & Quality Manager', company="Dream guy's Technologies", duration='2019-01 to 2020-11', responsibilities='N/A')] skills=['Business Analyst', 'Product development', 'Workflow Analysis', 'Quality assurance', 'Project Management', 'Business process mapping'] awards_and_honors=[] certifications=[] projects=[]
# full_name='MD Altaf Hussain' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='Software Engineer', company='GameCentrePlay', duration='N/A', responsibilities='Uldevelopment by using React JS with React Hooks, Managing application-Level state by using Redux and Redux hooks, Highly complex components designing by using React with minimum usage of third party NPM packages, Designing and using dynamic and reusable components, Implementation of connectivity with API services by using axios or fetch, Pushing and pulling code to GitHub repo, Design and develop static or dynamic components based on the requirements from product owner')] skills=['Uldevelopment by using React JS with React Hooks', 'Managing application-Level state by using Redux and Redux hooks', 'Highly complex components designing by using React with minimum usage of third party NPM packages', 'Designing and using dynamic and reusable components', 'Implementation of connectivity with API services by using axios or fetch', 'Pushing and pulling code to GitHub repo', 'Design and develop static or dynamic components based on the requirements from product owner'] awards_and_honors=[] certifications=[] projects=['GameCentrePlay']
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='Tableau Developer', company='N/A', duration='May 202 Til date', responsibilities='Requirement gathering and Created workbook & Dashboard, Analysis and create a wireframe for required data from Adobe XD and implemented the wireframe in tableau, Embedded tableau dashboards on SharePoint portal, Updating the dashboards according to the client requirements, Created Sites, Projects, Groups, Users, Scheduling, and Mall Subseription & User Filters on Tableau, Building Geographical charts like Symbol Maps and Filled Maps, Building various views using Sorting, Grouping, Dimension Hierarchies, Filters, Quick Filters, Actions, Sets, and Quick Table Calculations, Involved in deployment of the dashboards, Creating Test cases for user view to understand the workbook'), WorkExperience(job_title='Tableau Product Testing', company='N/A', duration='Nov 2020—Jun 2021', responsibilities='Developing a FTE dashboards for various departments, Giving KPI dashboard to give a quick employee count, Developing External start rate and regretted turnover rate Dashboard')] skills=['Tableau Desktop', 'Tableau Server', 'Tableau Prep', 'Adobe XB', 'MS Excel', 'MS Office'] awards_and_honors=[] certifications=[] projects=['Warranty & Claim, Sales Analyties', 'Human resource management']
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[] skills=['UI development by using React JS', 'Managing application-level state by using Redux and Redux hooks', 'Responsive web design by using React Bootstrap, HTML5, CSS3', 'Designing and using dynamic and reusable components', 'Implementation of connectivity with API services by using fetch', 'Pushing and pulling code to GitHub repo'] awards_and_honors=[] certifications=[] projects=['FICS Trial Management: Role: Software Engineer. Description: Geigene Health Care project for managing and tracking the cancer patient record. In this project we were aimed to build all sites using Reacts.', 'Justransact: Role: Software Engineer. Description: A complete E-commerce website to buy POS products throughout India, Justransact provides services including buy online, product comparison, email orders, online payment and logistics etc.', 'GSK Wave $: Role: Software Engineer. Description: GSK is a healthcare company aiming to create 44 regional websites on its products information. In this project we were aimed to build all sites using Reacts and Mongodb. React is used for front end and mongodb is used for backend.']
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='Freelancer Front-End Developer', company='N/A', duration="Jan'20~May'21", responsibilities='Working on with Javascript, React and Redux'), WorkExperience(job_title='Front-End Developer', company='Samata Corporation', duration="May'21~T Data Working", responsibilities='Working on with Javascript, React and Redux'), WorkExperience(job_title='Assistant Manager - Sourcing Lead (WM division)', company='Haler Appliances (1) Pvt Ltd. Pune', duration="Sep'1-May'21", responsibilities='Performing various activities like Hosting RFQ to suppliers, purchasing BOM items; ensuring cost optimization and analysing risk in supply contracts & agreements. Facilitating material management including capacity planning, scheduling, Inventory turn, new project/capital. Managing sourcing of plastic parts (moulded parts) packaging & sheet metal material: RM Plastic Resins (PP, ABS HIPS, Master Batches). Monthly Plastic Resins procurement from Vendors like Ril, IOCL, LG, Seyrolution, Bhansal etc. Capacity analysis of Machines and Molds against OFS/ plan.')] skills=['Javascript', 'React', 'Redux', 'Hosting RFQ to suppliers', 'Purchasing BOM items', 'Cost optimization', 'Risk analysis in supply contracts & agreements', 'Material management', 'Capacity planning', 'Scheduling', 'Inventory turn', 'New project/capital', 'Managing sourcing of plastic parts (moulded parts) packaging & sheet metal material', 'RM Plastic Resins (PP, ABS HIPS, Master Batches)', 'Monthly Plastic Resins procurement from Vendors like Ril, IOCL, LG, Seyrolution, Bhansal etc.', 'Capacity analysis of Machines and Molds against OFS/ plan'] awards_and_honors=[] certifications=[] projects=['Performance Development and Improvement (PDAI)- The project is for the elite Mercedes AMG Petronas team. Technologies used: React, Redux middleware (Redux Observables)']
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='N/A', company='N/A', duration='Jun 2013 - Dec 2013', responsibilities='N/A'), WorkExperience(job_title='N/A', company='N/A', duration='Nov 2012 - May 2013', responsibilities='N/A'), WorkExperience(job_title='N/A', company='N/A', duration='Sep 2011 - Oct 2012', responsibilities='N/A'), WorkExperience(job_title='N/A', company='N/A', duration='Jun 2010 - Aug 2011', responsibilities='N/A'), WorkExperience(job_title='N/A', company='N/A', duration='Apr 2009 - May 2010', responsibilities='Responsible for designing and developing Patient Appointment system for Nuclear medicine department'), WorkExperience(job_title='N/A', company='N/A', duration='Oct 2008 - Mar 2009', responsibilities='N/A')] skills=[] awards_and_honors=[] certifications=[] projects=['Unplanned Maintenances (Defects)', 'Corrective Maintenance', 'Planned Maintenance System (Shipping Domain)', 'DS Procurement (Web and Wintorm)', 'Numls fodine 131 and Appointment (Health Care Domain)', 'Prepare Vessel Database: HQ']
# full_name='Akash Sunil Satunkhe' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='N/A', company='Sharp Call Tracking, US', duration='N/A', responsibilities='Involved in config for UI forms using VB.Net HTML and Javascript. Thea Set “Sever “Zora eeata obecte tke Stored Procedures, Views, and User Defined'), WorkExperience(job_title='N/A', company='CareNet US', duration='N/A', responsibilities='Project: Description: Care Not_pregancy. Contes prove accurate & helpful information in a Sisco crgantzation ta cntroa cook to persuade a praon notte have\'an avorion: Momaguartored it oP "Ronis of Sotware Requirement Speci from Project Ms')] skills=['VB.Net', 'HTML', 'Javascript', 'AJAX'] awards_and_honors=[] certifications=[] projects=[]
# full_name='Anitha Raj' phone_number='491-9080807257' email='amitharaj040i@gmail.com' linkedin_profile='N/A' education=[] work_experience=[] skills=['Azure SQL', 'App service', 'Azure cloud', 'Data Migration', 'Team player', 'Quick learner'] awards_and_honors=[] certifications=[] projects=['Document Management']
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='Software Engineer', company='N/A', duration='N/A', responsibilities='Designing and developing web pages using Reactjs, Redux, HTMLS, €553, Bootstrap, JavaScript and Material.ui. Developed the application for responsive to different screen resolutions using Bootstrap and CSS3 media quiere. Managing application-tevel state by using Redux and Redux hooks. Designing and using dynamic and reusable components. Design and develop static or dynamic components based on the requirements from product owner.'), WorkExperience(job_title='Software Engineer', company='N/A', duration='N/A', responsibilities='Ul development by using React JS with React Hooks. Managing application-level state by using Redux and Redux hooks. Highly complex components designing by using React with minimum usage of third party NPM packages. Designing and using dynamic and reusable components. Imptementation of connectivity with API services by using axios or fetch. Pushing and pulling code to GitHub repo. Design and develop static or dynamic components based on the requirements from product owner.')] skills=['Reactjs', 'Redux', 'HTMLS', 'Bootstrap', 'JavaScript', 'Material.ui', 'CSS3', 'React Hooks', 'axios', 'fetch', 'GitHub'] awards_and_honors=[] certifications=[] projects=['Vehicle Management System (VHMS)']
# full_name='Gayatri Bendre' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[] skills=['English', 'Hindi', 'Marathi'] awards_and_honors=[] certifications=[] projects=[]
# full_name='Akshaya Khadke' phone_number='7385050500' email='akshayaharhate1298@gmail.com' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='Software Test Engineer', company='Arthat Business Private Limited', duration='N/A', responsibilities='Experience in Selenium Web driver with java, API[POSTMAN] and Web Services[SOAP UI]. Worked on page object model (POM) design pattern using Selenium web Driver and also integrated TestNG. Hands-on experience in different types of testing [Functional, Sanity, smoke, Regression, Retesting, cross browser, Adhoc -Data Driven testing etc]. Proficient in creating Test cases, Test Data as per requirements and Executing Test scenarios. Handled all kinds of roles and responsibilities as a QA in current project. Knowledge on Git versioning and Jenkins CI/CD pipeline execution. Have good knowledge on JAVA OOPS concepts and core Java. Expertise in using defect tracking tool like Jira tool. Have worked on creating Gradle projects for building, testing and maintaining project execution and good Knowledge on maven. Involved in designing, modifying, and enhancing both manual Test cases and test scripts and automating those. Having good in testing concepts like SDLC, STLC and different types of testing. Good understanding of software architecture like REST APIs. Experience of working in an Agile Development environment.')] skills=['Selenium Web driver with java', 'API[POSTMAN]', 'Web Services[SOAP UI]', 'Page object model (POM) design pattern', 'TestNG', 'Functional Testing', 'Sanity Testing', 'Smoke Testing', 'Regression Testing', 'Retesting', 'Cross Browser Testing', 'Adhoc -Data Driven testing', 'Test Case Creation', 'Test Data Creation', 'Test Scenario Execution', 'Git versioning', 'Jenkins CI/CD pipeline execution', 'JAVA OOPS concepts', 'Core Java', 'Jira tool', 'Gradle projects', 'Maven', 'Manual Test cases', 'Test scripts', 'SDLC', 'STLC', 'REST APIs', 'Agile Development environment'] awards_and_honors=[] certifications=[] projects=[]
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='N/A', company='Bridgepoint Capital, UK', duration='N/A', responsibilities='Meeting with the software product designers to determine quality assurance parameters. Writing & reviewing Test cases. Overseeing the drafting of testing documents. Leading the QA team in designing QA test procedures. Implementing testing procedures and overseeing the QA process. Constructing analysis checks on product specifications. Test Reporting. Ensuring the successful deployment of products into the market. Responding requests from the design team and management. Identifying software application weaknesses and target areas. Sketching out ideas for automated software test procedures. Collaborating with the design team to solve application faults. Defect Reporting and Tracking using any Defect Management Tool. Modifying Tests and performing Re & Regression Testing. Responsible for testing. Contributes to the team and works independently. Able to do both Automation and manual testing. Developing POM classes and Test classes. Prepare test plan and test cases. Involved in the peer review of the script and presenting demo to the client. Used existing DataDriven Framework for the test script execution.')] skills=['Quality Assurance', 'Test Case Writing & Review', 'Overseeing Testing Documents', 'QA Test Procedures Design', 'Implementing Testing Procedures', 'Product Specification Analysis', 'Test Reporting', 'Product Deployment', 'Software Application Weakness Identification', 'Automated Software Test Procedures Design', 'Collaboration', 'Defect Reporting and Tracking', 'Test Modification & Regression Testing', 'Automation and Manual Testing', 'POM Classes and Test Classes Development', 'Test Plan and Test Cases Preparation', 'Peer Review', 'DataDriven Framework Usage'] awards_and_honors=[] certifications=[] projects=['Bridgepoint Capital, UK']
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[Education(degree='B.E', major='Mechanical Engineering', institution='University of Pune', graduation_date='2014'), Education(degree='Diploma', major='Mechanical Engineering', institution='MAHETE', graduation_date='2011')] work_experience=[WorkExperience(job_title='Asst Manager ~ Buyer', company='U6 Electronic India Pvt. Ltd, Pune', duration="Since Sep'10", responsibilities='Procurement Sourcing, Worked as task member in stabilization of second REF tine (vendor ina, space & delivery being major constrains)')] skills=['Procurement Sourcing'] awards_and_honors=[] certifications=[] projects=[]
# full_name='Raviteja Moolinti Nallakkagari' phone_number='716-936-6677' email='mnoolint@buffalo.edu' linkedin_profile='www.linkedin.com/in/munraviteja' education=[Education(degree='MS in Computer Science and Engineering (AI/ML Track)', major='Computer Science and Engineering', institution='University at Buffalo, The State University of New York', graduation_date='December 2024'), Education(degree='Bachelor of Technology in Computer Science and Engineering', major='Computer Science and Engineering', institution='Sri Venkateswara University', graduation_date='June 2022')] work_experience=[WorkExperience(job_title='Research Assistant', company='University at Buffalo, The State University of New York', duration='January 2023 - Present', responsibilities='Employed Large Language Models (LLMs) with prompt engineering to extract synthesis and activation conditions from 1000+ MOF research papers, achieving 96% accuracy. Implemented predictive models correlating synthesis parameters with material performance metrics, reducing trial-and-error by 75% and saving 10 hours per experiment, optimizing experimental planning. Streamlined data processing and analysis workflows, reducing manual effort by 50% and time spent on data extraction and analysis by 30%. Automated scraping of research articles using Python and Selenium, efficiently gathering large dataset for analysis.'), WorkExperience(job_title='Associate Software Engineer (Machine Learning Engineer)', company='Infor', duration='October 2022 - August 2023', responsibilities='Collaborated to develop an NLP system that translates natural language queries into structured SQL queries, aiding customers with limited SQL knowledge. Leveraged Hugging Face models to develop and deploy text summarization tools, reducing processing time by 30%. Delivered measurable results within weeks, including anomaly detection, pricing decisions, cost reduction, and demand forecasting. Increased cross-selling revenue by 20% by implementing personalized product recommendations based on customer behavior and historical data.'), WorkExperience(job_title='Development Intern', company='Infor', duration='April 2022 - October 2022', responsibilities='Engaged in cross-functional collaboration to collect requirements, build, and evaluate models and present findings to customers. Enhanced SQL queries to boost data extraction efficiency, lessening processing times by 40%, and decreasing average query time from 10 seconds to 6 seconds. Utilized PySpark for handling large-scale data, lowering response times to under 1 second for most use cases via the Infor ION API Gateway, enhancing real-time data processing by 20%. Configured workflows for periodic execution of ML pipelines, automating retraining with new data to reduce manual intervention by 50% and save 10 hours weekly.'), WorkExperience(job_title='Intern', company='Codinza', duration='March 2019 - July 2019', responsibilities='Designed and deployed dynamic web applications using MongoDB, Express, React, and NodeJS (MERN stack). Created responsive UIs and RESTful APIs, decreasing bug reports by 40%.')] skills=['Python', 'C', 'C#', 'R', 'PyTorch', 'Tensorflow', 'PySpark', 'MySQL', 'PostgreSQL', 'MongoDB', 'React', 'Node.js(Express)', 'Flask', 'Generative AI', 'Machine Learning', 'Deep Learning', 'RL', 'Docker', 'Git', 'VS Code', 'AWS'] awards_and_honors=['Won the Institute Innovation Cell Award among 600+ students for adding attendance management and alumni connections to college website.', 'Mentored students by conducting over 20+ sessions on machine learning as a part of instructional team of coding club at Sri Venkateswara University.'] certifications=[] projects=['Language translation: Developed and trained multiple models for English to German translation, including LSTM, GRU, LSTM with attention, and Transformer architectures. Fine-tuned the mT5 model, achieving a BLEU score of 40.25 on the Multi30k dataset, ranking in the top 3 scores to date.', 'Network Intrusion ...
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='Business Analyst / QA Lead, QA Lead, Developer', company='TATA Consultancy Services', duration='N/A', responsibilities='Modified the existing QA processes, Introduced JIRA Process and Agile flow to the team, Monitored the status of full lifecycle testing of Application, Teamed with IT developers in testing new applications, Resolved testing issues related to building codes and code releases, Assessed impact of current business processes on Users and stakeholders, Taught employees how to control risks at front line, Analyzed key aspects of business to evaluate factors driving results, Written User stories for client requirements, Involved in discussion with Product owner for user story approval and sprint planning')] skills=['QA processes', 'JIRA Process', 'Agile flow', 'Full lifecycle testing', 'Collaboration with IT developers', 'Code building and release', 'Business process impact assessment', 'Risk control', 'Business analysis', 'User story writing', 'Sprint planning'] awards_and_honors=[] certifications=[] projects=['Yos! Health, Healthcare Product', 'British Airways', 'CE-RBL, Royal Bank of Scotland']
# ...
# full_name='Tecnmicat Acumen' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='Mobile App Developer', company='BikePool - Phase 1', duration='N/A', responsibilities='Involved in understanding the business functionality of the application. Involved in peer code reviews. Involved in Full Stack Development of certain components starting from Ul to REST ‘Apl and deployment. Involved in al standard Scrum & Pl ceremonies.')] skills=['Android Studio', 'Gitlabs', 'Github', 'JIRA', 'BitBucket', 'Asana', 'Trello', 'Source Tree', 'SUN', 'Firebase Postman', 'JAVA', 'xen', 'Kotlin', 'Partial Knowledge of Dart', 'PHP', 'satire', 'REST APL', 'Windows XP/7/10', 'UNIK.MAG 05', 'Ubuntu', 'Paypal Stripe', 'RazorPay', 'Paytm', 'UPL'] awards_and_honors=[] certifications=[] projects=['BikePool - Phase 1']
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='Software Programmer', company='Speak Support Pvt Ltd', duration='April 2012 to August 2015', responsibilities='Worked on On Cloud CRM Project for the Company. Developed windows based CRM application with SQL database. Developed 3 Applications: 1. On Cloud CRM Admin 2. On Cloud CRM Agent 3. On Cloud CRM Customer')] skills=['AWS Elastic Beanstalk', 'AWS S3 Bucket API', 'Elastic Load Balancer (ELB)', 'AWS SES API', 'C#', 'MS SQL', 'Infragistics', 'AWS'] awards_and_honors=[] certifications=[] projects=['On Cloud CRM Project']
# full_name='Jeethendrakumar Chandrasekaran' phone_number='7358502545' email='jecherahume9994@gmail.com' linkedin_profile='esthendrumae Chandischn' education=[] work_experience=[WorkExperience(job_title='Software Engineer', company='Prodapt Solutions', duration='April 2022 - present', responsibilities='N/A'), WorkExperience(job_title='Associate Software Engineer', company='Prodapt Solutions', duration='September 2020 — April 2022', responsibilities='N/A'), WorkExperience(job_title='Mobile and Web development', company='Code Bind Technologies', duration='N/A', responsibilities='N/A')] skills=['Database MYSQL', 'Resi', 'Ian'] awards_and_honors=[] certifications=[] projects=[]
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='Automation Test Engineer', company='Integrin Technologies', duration='From 13th Jan 2020 to till date', responsibilities='Understand the SRS document and analyze the requirement, Execute the testcase to validate customer requirement, Involved in review test case and send review comments to colleagues, Prepared mapping between requirement and test cases, Participate in scrum meeting to discuss about project progress report every day, Executing the test cases manually, Strong knowledge over whole Software Test Life Cycle (STLC), Development of test code in Java language using Eclipse IDE and TestNG Framework, Involvement in development of common functions/ Utility methods, Writing Selenium Web Driver scripts for regression and Data Driven framework for Functional testing, Integration of hybrid framework and Page Object Model for some modules, Verification of test results and logging defects, Performing cross browser testing by test scripts execution on IE, Firefox and Chrome, Development of scripts to read and write test data from/to excel sheets, Reporting the bugs in Jira, Helping in building and deployment using Jenkins, Generation of logs using Logi and test report using extent reports')] skills=['Selenium WebDriver', 'Data Driven framework', 'POM', 'TestNG', 'POI', 'Logi', 'AutoIT', 'JIRA', 'Java', 'Eclipse IDE', 'Cross browser testing', 'Script development', 'Bug reporting', 'Building and deployment using Jenkins', 'Generation of logs and test reports'] awards_and_honors=[] certifications=[] projects=['Ecommerce Website', 'Customer Relationship Management (CRM-Tech)']
# full_name='Antony Raj .S' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='Project Leader', company='Eurotech Gas Service', duration='April 02 2018 ~ August 20 2018', responsibilities='Project TIS CRM')] skills=[] awards_and_honors=[] certifications=[] projects=['Project 7: ETGS (Eurotech Gas Service)', 'Project TIS CRM']
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[] skills=[] awards_and_honors=[] certifications=[] projects=[]
# full_name='maura erenmel ase' phone_number='00202' email='N/A' linkedin_profile='N/A' education=[] work_experience=[] skills=[] awards_and_honors=[] certifications=[] projects=[]
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='Automation Test Eng', company='Domain 2 Airline Domain', duration='N/A', responsibilities='Enhancing Test Cases using pre. Feature flow Control Statements, exception handling, Conditional adding Comment, error handling verification, testing framework, data driven Testing, cross browser testing executing same functionality with multiple, Analyzing test result & reporting defects, Selecting test cases for regression testing, defect tracking, Regression testing on modify builds, Final regression testing'), WorkExperience(job_title='Software Test Engineer', company='Investment Banking', duration='N/A', responsibilities="Understood Project requirements, Prepare Test Cases, Execute the test cases to validate customer requirements, Sending the regular status to the higher authorities in timely manner, Retesting on Bug's fixed and performed Regression Testing")] skills=['Test Cases Enhancement', 'Feature flow Control Statements', 'Exception handling', 'Conditional adding Comment', 'Error handling verification', 'Testing framework', 'Data driven Testing', 'Cross browser testing', 'Test result analysis', 'Defect reporting', 'Regression testing', 'Defect tracking', 'Project requirements understanding', 'Test Cases Preparation', 'Test Cases Execution', 'Status reporting', "Retesting on Bug's fixed"] awards_and_honors=[] certifications=[] projects=['Domain 2 Airline Domain', 'Investment Banking']
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='Senior Software Developer', company='Speak Support Pvt Ltd', duration='Aug 2015 to Ds', responsibilities='Worked on Desktop and Web Application for absecure.com. Developed and deployed both web applications (app.qbsecure.com and webhook) and Desktop applications. Developed Framework for wabhook, Payment Page integration with Braintree via Net Core APIs. Architected & Developed Web API & Security Module to authenticate API call. Developed windows service for automated email sending service(reminders) via AWS SES API. Developed Application with VSS (Virtual Shadow Copy).'), WorkExperience(job_title='N/A', company='ArisGlobal', duration='N/A', responsibilities='Worked on Project involving sharepoint activities such writing Script and utlty for data migration. Also worked on Design and Ul integration with Sharepoint.'), WorkExperience(job_title='N/A', company='CMP', duration='N/A', responsibilities='Worked on a project to manage resources and stacks on a public or private cloud via API. With backend as NodeJs, Net Core (micro service web api architecture) and Front End as angular developed and architected the application.')] skills=['C#', 'Javascript', 'CSS HTML', 'JQuery', '.Net Core 3.1', 'Bootstrap', 'Angular (7,9) Fontend', 'MongoDB', 'MS SQL'] awards_and_honors=[] certifications=[] projects=['ArisGlobal Project involving sharepoint activities', 'CMP project to manage resources and stacks on a public or private cloud via API', 'Desktop and Web Application for absecure.com']
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[] skills=['React Js', 'MongoDB', 'Nodejs', 'ExpressJs', 'Angular Js', 'Golang'] awards_and_honors=[] certifications=[] projects=['YOU App', 'Ns-Vendor-Experience-APi', 'Ecommerce', 'Lawyer Management', 'SingShala', 'legably-ns']
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[] skills=[] awards_and_honors=[] certifications=[] projects=["Oreenieation —: Saxon.Al Description: : saxon le'a data and analytics company with end-to-end data engineering nd analytics services leveraging next-gen technologies from eading market vendors"]
# full_name='T. Baskaran' phone_number='+91-99444-27195' email='baskaran.corpusia@gmail.com' linkedin_profile='N/A' education=[] work_experience=[] skills=['SQA Testing & Methodologies', 'Sync & Smoke Testing', 'Tracking Logging & Reporting', 'Test Plans, Cases & Processes', 'Functional Requirements', 'Scripting & Documentation', 'Regression & Negative Testing', 'UI & Compatibility Testing', 'Data Interface & Migration Testing', 'Performance/Load/Stress Testing', 'Testing Automation', 'Defect/Bug Tracking', 'Test Strategies & Coverages', 'QA & QC Standards'] awards_and_honors=[] certifications=[] projects=[]
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='Software Test Engineer', company='Capgemini Company', duration='Jan 2019 to present', responsibilities='Go through the software requirements SRS document. Analysis of Requirement [Functional, Design] document. Prepare Analysis and Execution of Test Cases Also Prepare Test Summaries. Performed Functionality Testing, Retesting, Regression Testing and making the status in the defect management tool JIRA. Identify the regression test cases for Automation and Scripts updating. Also involved in Automation Testing using Selenium Webdriver. Provide regular reports on various aspects of projects underway. Ensure on-time deliveries. Verifying the Database using SQL queries and executes SQL queries for getting data from the database to do testing. Co-ordinate with client on daily basis.')] skills=['Repository management', 'Continuous Integration', 'Java programming', 'Selenium Web Driver', 'MAVEN', 'Locating elements using XPATH', 'Good communication', 'Collaboration', 'Grasping new technical concepts quickly', 'Functionality Testing', 'Retesting', 'Regression Testing', 'Automation Testing', 'SQL'] awards_and_honors=[] certifications=[] projects=['Investment Banking - Quality Capital markets: Piper Sandler originate structure and execute equity financings for private and public corporates through a variety of offerings like Initial Public Offerings (IPOs), Follow-on Public Offerings (FPOs), Qualified Institutional Placements (IP), Rights Issues, Private Placements, Block Trades, Pre- IPO Placements, Buybacks etc.']
# full_name='Krishnajagan G' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[] skills=['JAVA Web Applications', 'Web Application monitoring tools', 'ITIL Process', 'Analytical and problem solving skills', 'Adaptability', 'Multitasking', 'SOAP UI', 'Splunk', 'Control-M & Tidal Scheduler', 'Openshift', 'Science Logic AppD', 'ServiceNow', 'Udeploy', 'WinSCP', 'Jira', 'Confluence', 'Stack', 'REST API', 'Oracle SQL', 'MongoDB', 'Eclipse', 'UNIX & Windows', 'Version control tool'] awards_and_honors=[] certifications=[] projects=[]
# full_name='N/A' phone_number='N/A' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='N/A', company='N/A', duration='N/A', responsibilities='Worked on enhancement projects, Initiated and scheduled the Informatica jobs')] skills=[] awards_and_honors=[] certifications=[] projects=[]
# full_name='Anjali' phone_number=None email=None linkedin_profile=None education=[Education(degree='eee', major='N/A', institution='Veer Bahadur Singh Purwanchal University', graduation_date='N/A'), Education(degree='Diploma', major='N/A', institution='Govt. Girls Polytechnic Balla', graduation_date='2014'), Education(degree='X®', major='N/A', institution='Seva Sangh Inter College', graduation_date='2011')] work_experience=[] skills=['C#', 'Xamarin Forms', 'Web API', 'MVVM', 'FCM', 'Signal', 'OpenTok', 'Microsoft Visual Studio 2019', 'Microsoft SQL Server'] awards_and_honors=[] certifications=[] projects=['ZobleProductions : (Mobile App : Android & 105)', 'Fuser? : (Mobile App : Android & 10S)', 'Unlimitedcook : (Mobile App : Android & 105)']
# full_name='Ganesh Biradar' phone_number='+91-7030876676' email='ganesh3biradar@gmail.com' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='Software Test Engineer', company='N/A', duration='2.5 years', responsibilities='Manual and Automation testing (Using Selenium with JAVA), API/Webservice testing, Mobile Testing, Manual Testing, Functional testing, Api Testing, Automation Testing, Selenium WebDriver with Java, API testing with POSTMAN, Agile Methodology, Test Scenarios, Test Cases and Defect log, Smoke testing, System & functional testing, Regression and Retesting, JAVA, OOPS Concepts, Collections, Exceptions Handling, String Class, Executing test scripts on Edge, Firefox and Google chrome, identifying web Elements using Xpath, Xpath Expressions, handling popups and List Box, TestNG, Annotations and Keywords, Designing POM classes, Test Execution Process, Defect life Cycle and Test Plan, Test Scenarios and Design Test cases in Excel sheet, Execute the test case and prepares test proof, Raising the defect in IRA tool and preparing defect report, Test Lead to prepare Test summary report, Smoke Testing, System and Functional testing, Retesting & Regression, Worked closely with development team')] skills=['Manual and Automation testing', 'Selenium with JAVA', 'API/Webservice testing', 'Mobile Testing', 'Functional testing', 'Api Testing', 'Automation Testing', 'Selenium WebDriver with Java', 'API testing with POSTMAN', 'Agile Methodology', 'Test Scenarios', 'Test Cases and Defect log', 'Smoke testing', 'System & functional testing', 'Regression and Retesting', 'JAVA', 'OOPS Concepts', 'Collections', 'Exceptions Handling', 'String Class', 'Executing test scripts on Edge, Firefox and Google chrome', 'identifying web Elements using Xpath', 'Xpath Expressions', 'handling popups and List Box', 'TestNG', 'Annotations and Keywords', 'Designing POM classes', 'Test Execution Process', 'Defect life Cycle and Test Plan', 'Test Scenarios and Design Test cases in Excel sheet', 'Execute the test case and prepares test proof', 'Raising the defect in IRA tool and preparing defect report', 'Test Lead to prepare Test summary report', 'Smoke Testing', 'System and Functional testing', 'Retesting & Regression'] awards_and_honors=[] certifications=[] projects=[]
# full_name='ierenieiarmaterrnatici' phone_number='500004633' email='N/A' linkedin_profile='N/A' education=[] work_experience=[WorkExperience(job_title='Software Developer', company='N/A', duration='N/A', responsibilities='Software Development Life Cycle (SOLC) including Requirements gather, web developing using ASPNet core, ASPNet, HTMLS, CSS, React, Javascript, making Responsive Web Pages under Agile Scrum Methodologies, involved in Sprint Showcase, Provides after hours technology support')] skills=['ASPNet core', 'ASPNet', 'HTMLS', 'CSS', 'React', 'Javascript', 'Agile Scrum Methodologies', 'Responsive Web Pages', 'Software Development Life Cycle (SOLC)', 'Requirements gathering'] awards_and_honors=[] certifications=[] projects=[]

# %%
import pandas as pd
df = pd.read_csv('documents.csv')
df
# Out:
#                  full_name            phone_number  \
# 0                      NaN                     NaN
# 1           Aakash Sotunke  579897022 / 7585765171
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4     Aniket Bharat Kakade                     NaN
# ..                     ...                     ...
# 93          Krishnajagan G                     NaN
# 94                     NaN                     NaN
# 95                  Anjali                     NaN
# 96          Ganesh Biradar          +91-7030876676
# 97  ierenieiarmaterrnatici               500004633
#
#                           email linkedin_profile                  degree1  \
# 0                           NaN              NaN                      MBA
# 1   aakashsotunkezn9eqamaiiicom              NaN  Bachelor of Engineering
# 2                           NaN              NaN                      NaN
# 3                           NaN              NaN                      NaN
# 4                           NaN              NaN                      NaN
# ..                          ...              ...                      ...
# 93                          NaN              NaN                      NaN
# 94                          NaN              NaN                      NaN
# 95                          NaN              NaN                      eee
# 96     ganesh3biradar@gmail.com              NaN                      NaN
# 97                          NaN              NaN                      NaN
#
#                      major1                              institution1  \
# 0   Business Administration                   OR. CV Raman University
# 1                       NaN                           Pune University
# 2                       NaN                                       NaN
# 3                       NaN                                       NaN
# 4                       NaN                                       NaN
# ..                      ...                                       ...
# 93                      NaN                                       NaN
# 94                      NaN                                       NaN
# 95                      NaN  Veer Bahadur Singh Purwanchal University
# 96                      NaN                                       NaN
# 97                      NaN                                       NaN
#
#    graduation_date1  degree2    major2  ...             duration1  \
# 0               NaN    B.com  Commerce  ...                   NaN
# 1              2018      HSC       NaN  ...          2021-Present
# 2               NaN      NaN       NaN  ...  June 2019 to present
# 3               NaN      NaN       NaN  ...   Aug 2019 to present
# 4               NaN      NaN       NaN  ...                   NaN
# ..              ...      ...       ...  ...                   ...
# 93              NaN      NaN       NaN  ...                   NaN
# 94              NaN      NaN       NaN  ...                   NaN
# 95              NaN  Diploma       NaN  ...                   NaN
# 96              NaN      NaN       NaN  ...             2.5 years
# 97              NaN      NaN       NaN  ...                   NaN
#
#                                     responsibilities1  \
# 0   Designing and developing web pages using React...
# 1   Normalizing, Grouping, Cleaning data of pf, ex...
# 2   Analyzing & validating the completeness of bus...
# 3   Prepare reusable methods to improve productivi...
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94  Worked on enhancement projects, Initiated and ...
# 95                                                NaN
# 96  Manual and Automation testing (Using Selenium ...
# 97  Software Development Life Cycle (SOLC) includi...
#
#                          job_title2                           company2  \
# 0                 Software Engineer   Learning Management System (LMS)
# 1                               NaN  Intelligic Software Pvt Ltd, Pune
# 2   Software Test Engineer (Intern)                   VCITY Technology
# 3                               NaN                                NaN
# 4                               NaN                                NaN
# ..                              ...                                ...
# 93                              NaN                                NaN
# 94                              NaN                                NaN
# 95                              NaN                                NaN
# 96                              NaN                                NaN
# 97                              NaN                                NaN
#
#                     duration2  \
# 0                         NaN
# 1        June 2020 - Dec 2020
# 2   January 2019 to June 2019
# 3                         NaN
# 4                         NaN
# ..                        ...
# 93                        NaN
# 94                        NaN
# 95                        NaN
# 96                        NaN
# 97                        NaN
#
#                                     responsibilities2  \
# 0   Learning Management System is designed to trac...
# 1                      Auto Insurance fraud detection
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                skills awards_and_honors  \
# 0   Reactjs; Redux; HTML5; CSS3; Bootstrap; JavaSc...               NaN
# 1   Python; MySQL; ML Model building; Data pre-pro...               NaN
# 2   Good understanding of Dynamic Xpath and Itrame...               NaN
# 3   Java language programming; Finding x path loca...               NaN
# 4   Operating systems; Testing Tools; Databases; M...               NaN
# ..                                                ...               ...
# 93  JAVA Web Applications; Web Application monitor...               NaN
# 94                                                NaN               NaN
# 95  C#; Xamarin Forms; Web API; MVVM; FCM; Signal;...               NaN
# 96  Manual and Automation testing; Selenium with J...               NaN
# 97  ASPNet core; ASPNet; HTMLS; CSS; React; Javasc...               NaN
#
#    certifications                                           projects
# 0             NaN        Trucktion; Learning Management System (LMS)
# 1             NaN                     Auto Insurance fraud detection
# 2             NaN                                                NaN
# 3             NaN                                              Kogan
# 4             NaN                                                NaN
# ..            ...                                                ...
# 93            NaN                                                NaN
# 94            NaN                                                NaN
# 95            NaN  ZobleProductions : (Mobile App : Android & 105...
# 96            NaN                                                NaN
# 97            NaN                                                NaN
#
# [98 rows x 24 columns]

# %%
df.to_csv('final_resume_info_extracted.csv',index=False)
